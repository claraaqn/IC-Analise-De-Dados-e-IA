# %%
import xarray as xr
import pandas as pd
import re
import numpy as np
from math import radians, cos

# %% [markdown]
# ## Ajuste de arquivo

# %% [markdown]
# Os dados dados que a gente vai trablhar vem inicialmente em um arquivo NetCDF que é um arquivo vetorial.
#
# As informaçlções da cidades pernambucnas vem em um arquivo csv com as cordenas em formato de string DMS (ex.: -07 graus 54 minutos 42 segundos), então faço a conversão dessa string para um numero decimal. Depois faço um ajuste de posição geográfica, pois nossos dados de pernambuco vão de -180° a 180° e no banco de dados da precipitação eles vão de  0° a 360°.

# %%
ds = xr.open_dataset('src\precip_mon_mean.nc')
cidades_df = pd.read_csv('src\Posição geográfica das sedes dos municípios.csv')

def converter_coordenada(coord_str):
    numeros = re.findall(r'-?\d+', str(coord_str))
    if len(numeros) < 3:
        raise ValueError(f"Formato inválido de coordenada: {coord_str}")
    graus, minutos, segundos = map(int, numeros[:3])
    sinal = -1 if graus < 0 else 1
    return sinal * (abs(graus) + minutos / 60 + segundos / 3600)

cidades_df['lat_decimal'] = cidades_df['Latitude'].apply(converter_coordenada)
cidades_df['lon_decimal'] = cidades_df['Longitude'].apply(converter_coordenada)
cidades_df['lon_ajustado'] = cidades_df['lon_decimal'].apply(lambda x: x % 360)

# %% [markdown]
# Eu extrai a série temporal de precipitação para cada cidade a partir dos dados de grade do NetCDF. O código percorre cada linha do DataFrame cidades_df, que contém as informações geográficas das cidades já com as coordenadas convertidas para o formato decimal e ajustadas. Aí vai ocorrer a seleção de dados de precipitação quando os ponte de latitude e longitude mais próximo. Converto os dados para DataFrame do pandas, pois facilita para mim.

# %%
registros = []

for idx, cidade in cidades_df.iterrows():
    dados = ds['precip'].sel(
        lat=cidade['lat_decimal'],
        lon=cidade['lon_ajustado'],
        method='nearest'
    )
    
    df_temp = dados.to_dataframe().reset_index()
    df_temp['Cidade'] = cidade['Cidade']
    df_temp['Latitude'] = cidade['lat_decimal']
    df_temp['Longitude'] = cidade['lon_decimal']
    
    registros.append(df_temp[['Cidade', 'time', 'precip', 'Latitude', 'Longitude']])
    print(f"Processado: {cidade['Cidade']} ({len(df_temp)} registros)")
# Out:
# Processado: Abreu e Lima (560 registros)
# Processado: Afogados da Ingazeira (560 registros)
# Processado: Afrânio (560 registros)
# Processado: Agrestina (560 registros)
# Processado: Água Preta (560 registros)
# Processado: Águas Belas (560 registros)
# Processado: Alagoinha (560 registros)
# Processado: Aliança (560 registros)
# Processado: Altinho (560 registros)
# Processado: Amaraji (560 registros)
# Processado: Angelim (560 registros)
# Processado: Araçoiaba (560 registros)
# Processado: Araripina (560 registros)
# Processado: Arcoverde (560 registros)
# Processado: Barra de Guabiraba (560 registros)
# Processado: Barreiros (560 registros)
# Processado: Belém de Maria (560 registros)
# Processado: Belém do São Francisco (560 registros)
# Processado: Belo Jardim (560 registros)
# Processado: Betânia (560 registros)
# Processado: Bezerros (560 registros)
# Processado: Bodocó (560 registros)
# Processado: Bom Conselho (560 registros)
# Processado: Bom Jardim (560 registros)
# Processado: Bonito (560 registros)
# Processado: Brejão (560 registros)
# Processado: Brejinho (560 registros)
# Processado: Brejo da Madre de Deus (560 registros)
# Processado: Buenos Aires (560 registros)
# Processado: Buíque (560 registros)
# Processado: Cabo de Santo Agostinho (560 registros)
# Processado: Cabrobó (560 registros)
# Processado: Cachoeirinha (560 registros)
# Processado: Caetés (560 registros)
# Processado: Calçado (560 registros)
# Processado: Calumbi (560 registros)
# Processado: Camaragibe (560 registros)
# Processado: Camocim de São Félix (560 registros)
# Processado: Camutanga (560 registros)
# Processado: Canhotinho (560 registros)
# Processado: Capoeiras (560 registros)
# Processado: Carnaíba (560 registros)
# Processado: Carnaubeira da Penha (560 registros)
# Processado: Carpina (560 registros)
# Processado: Caruaru (560 registros)
# Processado: Casinhas (560 registros)
# Processado: Catende (560 registros)
# Processado: Cedro (560 registros)
# Processado: Chã de Alegria (560 registros)
# Processado: Chã Grande (560 registros)
# Processado: Condado (560 registros)
# Processado: Correntes (560 registros)
# Processado: Cortês (560 registros)
# Processado: Cumaru (560 registros)
# Processado: Cupira (560 registros)
# Processado: Custódia (560 registros)
# Processado: Dormentes (560 registros)
# Processado: Escada (560 registros)
# Processado: Exu (560 registros)
# Processado: Feira Nova (560 registros)
# Processado: Fernando de Noronha (560 registros)
# Processado: Ferreiros (560 registros)
# Processado: Flores (560 registros)
# Processado: Floresta (560 registros)
# Processado: Frei Miguelinho (560 registros)
# Processado: Gameleira (560 registros)
# Processado: Garanhuns (560 registros)
# Processado: Glória do Goitá (560 registros)
# Processado: Goiana (560 registros)
# Processado: Granito (560 registros)
# Processado: Gravatá (560 registros)
# Processado: Iati (560 registros)
# Processado: Ibimirim (560 registros)
# Processado: Ibirajuba (560 registros)
# Processado: Igarassu (560 registros)
# Processado: Iguaracy (560 registros)
# Processado: Ilha de Itamaracá (560 registros)
# Processado: Inajá (560 registros)
# Processado: Ingazeira (560 registros)
# Processado: Ipojuca (560 registros)
# Processado: Ipubi (560 registros)
# Processado: Itacuruba (560 registros)
# Processado: Itaíba (560 registros)
# Processado: Itambé (560 registros)
# Processado: Itapetim (560 registros)
# Processado: Itapissuma (560 registros)
# Processado: Itaquitinga (560 registros)
# Processado: Jaboatão dos Guararapes (560 registros)
# Processado: Jaqueira (560 registros)
# Processado: Jataúba (560 registros)
# Processado: Jatobá (560 registros)
# Processado: João Alfredo (560 registros)
# Processado: Joaquim Nabuco (560 registros)
# Processado: Jucati (560 registros)
# Processado: Jupi (560 registros)
# Processado: Jurema (560 registros)
# Processado: Lagoa de Itaenga (560 registros)
# Processado: Lagoa do Carro (560 registros)
# Processado: Lagoa do Ouro (560 registros)
# Processado: Lagoa dos Gatos (560 registros)
# Processado: Lagoa Grande (560 registros)
# Processado: Lajedo (560 registros)
# Processado: Limoeiro (560 registros)
# Processado: Macaparana (560 registros)
# Processado: Machados (560 registros)
# Processado: Manari (560 registros)
# Processado: Maraial (560 registros)
# Processado: Mirandiba (560 registros)
# Processado: Moreilândia (560 registros)
# Processado: Moreno (560 registros)
# Processado: Nazaré da Mata (560 registros)
# Processado: Olinda (560 registros)
# Processado: Orobó (560 registros)
# Processado: Orocó (560 registros)
# Processado: Ouricuri (560 registros)
# Processado: Palmares (560 registros)
# Processado: Palmeirina (560 registros)
# Processado: Panelas (560 registros)
# Processado: Paranatama (560 registros)
# Processado: Parnamirim (560 registros)
# Processado: Passira (560 registros)
# Processado: Paudalho (560 registros)
# Processado: Paulista (560 registros)
# Processado: Pedra (560 registros)
# Processado: Pesqueira (560 registros)
# Processado: Petrolândia (560 registros)
# Processado: Petrolina (560 registros)
# Processado: Poção (560 registros)
# Processado: Pombos (560 registros)
# Processado: Primavera (560 registros)
# Processado: Quipapá (560 registros)
# Processado: Quixaba (560 registros)
# Processado: Recife (560 registros)
# Processado: Riacho das Almas (560 registros)
# Processado: Ribeirão (560 registros)
# Processado: Rio Formoso (560 registros)
# Processado: Sairé (560 registros)
# Processado: Salgadinho (560 registros)
# Processado: Salgueiro (560 registros)
# Processado: Saloá (560 registros)
# Processado: Sanharó (560 registros)
# Processado: Santa Cruz (560 registros)
# Processado: Santa Cruz da Baixa Verde (560 registros)
# Processado: Santa Cruz do Capibaribe (560 registros)
# Processado: Santa Filomena (560 registros)
# Processado: Santa Maria da Boa Vista (560 registros)
# Processado: Santa Maria do Cambucá (560 registros)
# Processado: Santa Terezinha (560 registros)
# Processado: São Benedito do Sul (560 registros)
# Processado: São Bento do Una (560 registros)
# Processado: São Caetano (560 registros)
# Processado: São João (560 registros)
# Processado: São Joaquim do Monte (560 registros)
# Processado: São José da Coroa Grande (560 registros)
# Processado: São José do Belmonte (560 registros)
# Processado: São José do Egito (560 registros)
# Processado: São Lourenço da Mata (560 registros)
# Processado: São Vicente Férrer (560 registros)
# Processado: Serra Talhada (560 registros)
# Processado: Serrita (560 registros)
# Processado: Sertânia (560 registros)
# Processado: Sirinhaém (560 registros)
# Processado: Solidão (560 registros)
# Processado: Surubim (560 registros)
# Processado: Tabira (560 registros)
# Processado: Tacaimbó (560 registros)
# Processado: Tacaratu (560 registros)
# Processado: Tamandaré (560 registros)
# Processado: Taquaritinga do Norte (560 registros)
# Processado: Terezinha (560 registros)
# Processado: Terra Nova (560 registros)
# Processado: Timbaúba (560 registros)
# Processado: Toritama (560 registros)
# Processado: Tracunhaém (560 registros)
# Processado: Trindade (560 registros)
# Processado: Triunfo (560 registros)
# Processado: Tupanatinga (560 registros)
# Processado: Tuparetama (560 registros)
# Processado: Venturosa (560 registros)
# Processado: Verdejante (560 registros)
# Processado: Vertente do Lério (560 registros)
# Processado: Vertentes (560 registros)
# Processado: Vicência (560 registros)
# Processado: Vitória de Santo Antão (560 registros)
# Processado: Xexéu (560 registros)

# %% [markdown]
# Estas duas linhas realizam a consolidação final dos dados processados e a padronização dos nomes das colunas para facilitar análises futuras.

# %%
df_final = pd.concat(registros, ignore_index=True)
df_final.rename(columns={'time': 'Data', 'precip': 'Precipitacao_mm_mes'}, inplace=True)

# %% [markdown]
# Salvo os dados

# %%
df_final.to_csv('src\precipitacao_cidades_pernambuco_temporal.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Analisando os dados de Pernambuco

# %%
dados_pe = pd.read_csv('src\precipitacao_cidades_pernambuco_temporal.csv')

# %% [markdown]
# Transformo o formato de datas que está em string no formato date

# %%
dados_pe['Data'] = pd.to_datetime(dados_pe['Data'])

# %% [markdown]
# Este bloco de código realiza uma verificação da integridade temporal dos dados de precipitação para uma cidade específica, identificando se existem meses faltantes na série histórica.

# %%
cidade = "Abreu e Lima"
df_cidade = dados_pe[dados_pe['Cidade'] == cidade].copy()

inicio = df_cidade['Data'].min()
fim = df_cidade['Data'].max()
datas_esperadas = pd.date_range(start=inicio, end=fim, freq='MS') 

datas_existentes = pd.to_datetime(df_cidade['Data'].unique())
datas_faltando = datas_esperadas.difference(datas_existentes)

print(f"esperado: {len(datas_esperadas)} meses ({inicio.year}–{fim.year})")
print(f"encontrado: {len(df_cidade)} meses")
print(f"Faltando {len(datas_faltando)} meses:")
# Out:
# esperado: 560 meses (1979–2025)
# encontrado: 560 meses
# Faltando 0 meses:

# %% [markdown]
# Verifico a média geral de todos os municipios

# %%
dados_pe.groupby('Cidade')['Precipitacao_mm_mes'].mean()
# Out:
# Cidade
# Abreu e Lima              3.057414
# Afogados da Ingazeira     3.053409
# Afrânio                   1.804672
# Agrestina                 3.337996
# Alagoinha                 3.337996
#                             ...
# Vicência                  3.337996
# Vitória de Santo Antão    3.337996
# Xexéu                     3.337996
# Água Preta                3.337996
# Águas Belas               3.337996
# Name: Precipitacao_mm_mes, Length: 185, dtype: float64

# %% [markdown]
# Verifico a variância de todos os municipios

# %%
dados_pe.groupby('Cidade')['Precipitacao_mm_mes'].var()
# Out:
# Cidade
# Abreu e Lima              10.116097
# Afogados da Ingazeira      8.561663
# Afrânio                    4.039630
# Agrestina                 12.128383
# Alagoinha                 12.128383
#                             ...
# Vicência                  12.128383
# Vitória de Santo Antão    12.128383
# Xexéu                     12.128383
# Água Preta                12.128383
# Águas Belas               12.128383
# Name: Precipitacao_mm_mes, Length: 185, dtype: float64

# %% [markdown]
# verifico o descio-padrão de todos os municipios

# %%
dados_pe.groupby('Cidade')['Precipitacao_mm_mes'].std()
# Out:
# Cidade
# Abreu e Lima              3.180581
# Afogados da Ingazeira     2.926032
# Afrânio                   2.009883
# Agrestina                 3.482583
# Alagoinha                 3.482583
#                             ...
# Vicência                  3.482583
# Vitória de Santo Antão    3.482583
# Xexéu                     3.482583
# Água Preta                3.482583
# Águas Belas               3.482583
# Name: Precipitacao_mm_mes, Length: 185, dtype: float64

# %% [markdown]
# ## Analise descritiva por Mesorregião

# %%
mesorregioes = pd.read_csv('src\mesorregios.csv')
dados_completos = pd.merge(dados_pe, mesorregioes, on='Cidade', how='left')

# %% [markdown]
# média por mesorregião

# %%
dados_completos.groupby('Mesorregião')['Precipitacao_mm_mes'].mean()
# Out:
# Mesorregião
# Agreste Pernambucano          3.337996
# Mata Pernambucana             3.252217
# Metropolitana do Recife       3.153292
# Sertão Pernambucano           2.806245
# São Francisco Pernambucano    2.720412
# Name: Precipitacao_mm_mes, dtype: float64

# %% [markdown]
# Variância por mesorregião

# %%
dados_completos.groupby('Mesorregião')['Precipitacao_mm_mes'].var()
# Out:
# Mesorregião
# Agreste Pernambucano          12.107030
# Mata Pernambucana             11.737468
# Metropolitana do Recife       10.581341
# Sertão Pernambucano            8.188738
# São Francisco Pernambucano     7.648501
# Name: Precipitacao_mm_mes, dtype: float64

# %% [markdown]
# Descio padrão por mesorregião

# %%
dados_completos.groupby('Mesorregião')['Precipitacao_mm_mes'].std()
# Out:
# Mesorregião
# Agreste Pernambucano          3.479516
# Mata Pernambucana             3.425999
# Metropolitana do Recife       3.252897
# Sertão Pernambucano           2.861597
# São Francisco Pernambucano    2.765592
# Name: Precipitacao_mm_mes, dtype: float64

# %% [markdown]
# salva os dados em um arquivo

# %%
dados_completos.to_csv('src\dados_completos.csv', index=False, encoding='utf-8')
